# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import f1_score

titanic = sns.load_dataset('titanic')
titanic.isnull().sum()


X = titanic[['pclass','sex','age','sibsp','parch','fare']]
Y = titanic['survived']

imputer = SimpleImputer(strategy = 'mean')
X['age'] = imputer.fit_transform(X[['age']])
X['fare'] = imputer.fit_transform(X[['fare']])
X['sex'] = LabelEncoder().fit_transform(X['sex'])

scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)
X_train, X_test, y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
model = AdaBoostClassifier(n_estimators = 100,learning_rate=0.05, random_state = 42)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
f1 = f1_score(Y_test,y_pred)
f1
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29024\758589294.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['age'] = imputer.fit_transform(X[['age']])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29024\758589294.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['fare'] = imputer.fit_transform(X[['fare']])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29024\758589294.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['sex'] = LabelEncoder().fit_transform(X['sex'])
# D:\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 0.7310344827586207

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## 타겟 특성 선택

# %%
X = titanic[['pclass','sex','age','sibsp','parch','fare']]
Y = titanic['survived']

# %%
imputer = SimpleImputer(strategy = 'mean')

# %%
# 결측치를 평균으로 대체, deck 열은 삭제
X['age'] = imputer.fit_transform(X[['age']])
X['fare'] = imputer.fit_transform(X[['fare']])
X['sex'] = LabelEncoder().fit_transform(X['sex'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29024\3787379608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['age'] = imputer.fit_transform(X[['age']])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29024\3787379608.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['fare'] = imputer.fit_transform(X[['fare']])
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_29024\3787379608.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['sex'] = LabelEncoder().fit_transform(X['sex'])

# %%
X['sex']
# Out:
# 0      0.737695
# 1     -1.355574
# 2     -1.355574
# 3     -1.355574
# 4      0.737695
#          ...
# 886    0.737695
# 887   -1.355574
# 888   -1.355574
# 889    0.737695
# 890    0.737695
# Name: sex, Length: 891, dtype: float64

# %%
scaler = StandardScaler()

# %%
X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)

# %%
X_train, X_test, y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
model = AdaBoostClassifier(n_estimators = 60, random_state = 42)

# %%
model.fit(X_train,y_train)
# Out:
# D:\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(n_estimators=60, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
f1 = f1_score(Y_test,y_pred)

# %%
f1
# Out:
# 0.7819548872180451
